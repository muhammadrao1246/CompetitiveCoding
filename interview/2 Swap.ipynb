# %%
# 2 SWAP
a= 5
b=6
a=a+b # 11
b=a-b # 11 - 6 = 5
a=a-b # 11 - 5 = 6
a,b
# Out:
# (6, 5)

# %%
a = 3
b = 7
a = a + b 
b = a - b 
a = a - b
a,b
# Out:
# (7, 3)

# %%
a = 5
b = 9
a = a+b 
b = a-b
a = a-b 
a,b
# Out:
# (9, 5)

# %%
a = 500
b = 400
print(a,b)
a = a+b # 900
b = a-b # 900-400 = 500
a = a-b # 900 - 500 = 400 

(a,b)
# Out:
# 500 400
# (400, 500)
